# %% [markdown]
# # Working with GOES LightCurves

# %% [markdown]
# ## Overview

# %% [markdown]
# A basic example working with GOES light curves in SunPy. Below, we generate a lightcurve for the previous day and create a simple plot.

# %%
# %matplotlib inline

from sunpy.lightcurve import GOESLightCurve
goes = GOESLightCurve.from_yesterday()
fig = goes.peek()
# Out:
# /home/stuart/.virtualenvs/sunpy_gallery/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))
# /home/stuart/.virtualenvs/sunpy_gallery/lib/python2.7/site-packages/sunpy/lightcurve/lightcurve.py:253: RuntimeWarning: Using existing file rather than downloading, use overwrite=True to override.
#   warnings.warn("Using existing file rather than downloading, use overwrite=True to override.", RuntimeWarning)
# /home/stuart/.virtualenvs/sunpy_gallery/lib/python2.7/site-packages/matplotlib/figure.py:371: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# To see what time-range the data is for, we can use the `time_range` method.

# %%
goes.time_range()
# Out:
#     Start: 2014/06/11 23:59:59
#     End:   2014/06/12 23:59:57
#     Center:2014/06/12 11:59:58
#     Duration:0 days or
#            1439.97433333 minutes or
#            86398.46 seconds

# %% [markdown]
# The underlying data is stored as a [pandas DataFrame](http://pandas.pydata.org/pandas-docs/dev/dsintro.html) object.

# %%
goes.data
# Out:
#                                     xrsa      xrsb
# 2014-06-11 23:59:59.291999  2.834900e-08  0.000002
# 2014-06-12 00:00:01.338999  2.723500e-08  0.000002
# 2014-06-12 00:00:03.388999  2.946400e-08  0.000002
# 2014-06-12 00:00:05.434999  2.946400e-08  0.000002
# 2014-06-12 00:00:07.481999  3.057800e-08  0.000002
# 2014-06-12 00:00:09.531999  2.946400e-08  0.000002
# 2014-06-12 00:00:11.578999  2.946400e-08  0.000002
# 2014-06-12 00:00:13.628999  3.057800e-08  0.000002
# 2014-06-12 00:00:15.674999  2.834900e-08  0.000002
# 2014-06-12 00:00:17.721999  2.834900e-08  0.000002
# 2014-06-12 00:00:19.771999  2.946400e-08  0.000002
# 2014-06-12 00:00:21.819000  2.612000e-08  0.000002
# 2014-06-12 00:00:23.868999  2.723500e-08  0.000002
# 2014-06-12 00:00:25.914999  2.389100e-08  0.000002
# 2014-06-12 00:00:27.961999  2.723500e-08  0.000002
# 2014-06-12 00:00:30.011999  2.500600e-08  0.000002
# 2014-06-12 00:00:32.059000  2.612000e-08  0.000002
# 2014-06-12 00:00:34.108999  2.389100e-08  0.000002
# 2014-06-12 00:00:36.154999  2.389100e-08  0.000002
# 2014-06-12 00:00:38.201999  2.612000e-08  0.000002
# 2014-06-12 00:00:40.251999  2.500600e-08  0.000002
# 2014-06-12 00:00:42.298999  2.612000e-08  0.000002
